# %%
import torch
from pipeline import pipeline, preprocessing
from hungq.util import generate_submission, sample

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DATA_PATH = '/data/train.txt'
TEST_PATH = '/data/test.txt'

data_bundle = preprocessing(DATA_PATH)
train_df, val_df, test_df, train_loader, val_loader, user_map, movie_map, n_users, n_movies, min_value, max_value = data_bundle
print(f"Users: {n_users}, Movies: {n_movies}")
trained_models = {}
# Out:
# Scaling ratings from [1, 5] to [0, 1].
# Users: 943, Movies: 1680

# %%
gmf_config = {
    'epochs': 7,
    'batch_size': 512,
    'learning_rate': 0.00065,
    'weight_decay': 1e-5,
    'embedding_dim': 64,
    'device': device
}
trained_models['gmf'] = pipeline('gmf', gmf_config, data_bundle)
# Out:
# Training Model: best_gmf
# Epoch 1/7 | Train Loss: 0.0757 | Val Loss: 0.0701 | Val RMSE: 1.0588
# Epoch 2/7 | Train Loss: 0.0689 | Val Loss: 0.0650 | Val RMSE: 1.0196
# Epoch 3/7 | Train Loss: 0.0624 | Val Loss: 0.0595 | Val RMSE: 0.9759
# Epoch 4/7 | Train Loss: 0.0553 | Val Loss: 0.0561 | Val RMSE: 0.9470
# Epoch 5/7 | Train Loss: 0.0495 | Val Loss: 0.0542 | Val RMSE: 0.9313
# Epoch 6/7 | Train Loss: 0.0445 | Val Loss: 0.0534 | Val RMSE: 0.9243
# Epoch 7/7 | Train Loss: 0.0399 | Val Loss: 0.0532 | Val RMSE: 0.9230
# Best Val RMSE: 0.9230
# Test RMSE: 0.9236

# %%
attn_config = {
    'epochs': 10,
    'batch_size': 512,
    'learning_rate': 0.002,
    'weight_decay': 1e-3,
    'embedding_dim': 64,
    'hidden_dims': [32],
    'n_attention_blocks': 2,
    'n_heads': 4,
    'dropout': 0.3,
    'device': device
}
trained_models['attention'] = pipeline('attention', attn_config, data_bundle)
# Out:
# Training Model: best_attention
# Epoch 1/10 | Train Loss: 0.0968 | Val Loss: 0.0637 | Val RMSE: 1.0096
# Epoch 2/10 | Train Loss: 0.0622 | Val Loss: 0.0582 | Val RMSE: 0.9652
# Epoch 3/10 | Train Loss: 0.0579 | Val Loss: 0.0563 | Val RMSE: 0.9489
# Epoch 4/10 | Train Loss: 0.0565 | Val Loss: 0.0562 | Val RMSE: 0.9484
# Epoch 5/10 | Train Loss: 0.0557 | Val Loss: 0.0555 | Val RMSE: 0.9423
# Epoch 6/10 | Train Loss: 0.0550 | Val Loss: 0.0551 | Val RMSE: 0.9389
# Epoch 7/10 | Train Loss: 0.0545 | Val Loss: 0.0552 | Val RMSE: 0.9397
# Epoch 8/10 | Train Loss: 0.0541 | Val Loss: 0.0546 | Val RMSE: 0.9345
# Epoch 9/10 | Train Loss: 0.0537 | Val Loss: 0.0546 | Val RMSE: 0.9347
# Epoch 10/10 | Train Loss: 0.0533 | Val Loss: 0.0549 | Val RMSE: 0.9370
# Best Val RMSE: 0.9345
# Test RMSE: 0.9397

# %%
ncf_config = {
    'epochs': 20,
    'batch_size': 256,
    'learning_rate': 0.001,
    'weight_decay': 0.001,
    'dropout': 0.3,
    'freeze_pretrained': False,
    'device': device
}
trained_models['ncf'] = pipeline('ncf', ncf_config, data_bundle, pretrained_models=trained_models)
# Out:
# Training Model: best_ncf
# Epoch 1/20 | Train Loss: 0.0610 | Val Loss: 0.0544 | Val RMSE: 0.9331
# Epoch 2/20 | Train Loss: 0.0535 | Val Loss: 0.0544 | Val RMSE: 0.9330
# Epoch 3/20 | Train Loss: 0.0522 | Val Loss: 0.0541 | Val RMSE: 0.9305
# Epoch 4/20 | Train Loss: 0.0516 | Val Loss: 0.0544 | Val RMSE: 0.9329
# Epoch 5/20 | Train Loss: 0.0508 | Val Loss: 0.0539 | Val RMSE: 0.9285
# Epoch 6/20 | Train Loss: 0.0503 | Val Loss: 0.0546 | Val RMSE: 0.9348
# Epoch 7/20 | Train Loss: 0.0500 | Val Loss: 0.0542 | Val RMSE: 0.9314
# Epoch 8/20 | Train Loss: 0.0493 | Val Loss: 0.0549 | Val RMSE: 0.9372
# Epoch 9/20 | Train Loss: 0.0468 | Val Loss: 0.0540 | Val RMSE: 0.9296
# Epoch 10/20 | Train Loss: 0.0462 | Val Loss: 0.0544 | Val RMSE: 0.9329
# Epoch 11/20 | Train Loss: 0.0457 | Val Loss: 0.0547 | Val RMSE: 0.9352
# Epoch 12/20 | Train Loss: 0.0438 | Val Loss: 0.0553 | Val RMSE: 0.9407
# Epoch 13/20 | Train Loss: 0.0431 | Val Loss: 0.0553 | Val RMSE: 0.9404
# Epoch 14/20 | Train Loss: 0.0430 | Val Loss: 0.0553 | Val RMSE: 0.9404
# Epoch 15/20 | Train Loss: 0.0419 | Val Loss: 0.0557 | Val RMSE: 0.9439
# Epoch 16/20 | Train Loss: 0.0412 | Val Loss: 0.0558 | Val RMSE: 0.9451
# Epoch 17/20 | Train Loss: 0.0411 | Val Loss: 0.0560 | Val RMSE: 0.9466
# Epoch 18/20 | Train Loss: 0.0404 | Val Loss: 0.0562 | Val RMSE: 0.9485
# Epoch 19/20 | Train Loss: 0.0403 | Val Loss: 0.0564 | Val RMSE: 0.9498
# Epoch 20/20 | Train Loss: 0.0401 | Val Loss: 0.0565 | Val RMSE: 0.9504
# Best Val RMSE: 0.9285
# Test RMSE: 0.9328

# %%
lightgcn_config = {
    'epochs': 40,
    'batch_size': 512,
    'learning_rate': 0.002,
    'weight_decay': 1e-6,
    'embedding_dim': 128,
    'n_layers': 6,
    'device': device,
    'train_df': data_bundle[0]
}
trained_models['lightgcn'] = pipeline('lightgcn', lightgcn_config, data_bundle)
# Out:
# Training Model: best_lightgcn
# Epoch 1/40 | Train Loss: 0.0685 | Val Loss: 0.0600 | Val RMSE: 0.9799
# Epoch 2/40 | Train Loss: 0.0578 | Val Loss: 0.0565 | Val RMSE: 0.9507
# Epoch 3/40 | Train Loss: 0.0544 | Val Loss: 0.0552 | Val RMSE: 0.9398
# Epoch 4/40 | Train Loss: 0.0527 | Val Loss: 0.0545 | Val RMSE: 0.9342
# Epoch 5/40 | Train Loss: 0.0517 | Val Loss: 0.0541 | Val RMSE: 0.9305
# Epoch 6/40 | Train Loss: 0.0507 | Val Loss: 0.0536 | Val RMSE: 0.9263
# Epoch 7/40 | Train Loss: 0.0497 | Val Loss: 0.0533 | Val RMSE: 0.9231
# Epoch 8/40 | Train Loss: 0.0489 | Val Loss: 0.0528 | Val RMSE: 0.9193
# Epoch 9/40 | Train Loss: 0.0484 | Val Loss: 0.0526 | Val RMSE: 0.9174
# Epoch 10/40 | Train Loss: 0.0476 | Val Loss: 0.0525 | Val RMSE: 0.9163
# Epoch 11/40 | Train Loss: 0.0471 | Val Loss: 0.0522 | Val RMSE: 0.9143
# Epoch 12/40 | Train Loss: 0.0466 | Val Loss: 0.0521 | Val RMSE: 0.9134
# Epoch 13/40 | Train Loss: 0.0462 | Val Loss: 0.0521 | Val RMSE: 0.9132
# Epoch 14/40 | Train Loss: 0.0458 | Val Loss: 0.0520 | Val RMSE: 0.9122
# Epoch 15/40 | Train Loss: 0.0454 | Val Loss: 0.0519 | Val RMSE: 0.9117
# Epoch 16/40 | Train Loss: 0.0449 | Val Loss: 0.0519 | Val RMSE: 0.9114
# Epoch 17/40 | Train Loss: 0.0447 | Val Loss: 0.0518 | Val RMSE: 0.9103
# Epoch 18/40 | Train Loss: 0.0438 | Val Loss: 0.0516 | Val RMSE: 0.9090
# Epoch 19/40 | Train Loss: 0.0432 | Val Loss: 0.0515 | Val RMSE: 0.9080
# Epoch 20/40 | Train Loss: 0.0424 | Val Loss: 0.0515 | Val RMSE: 0.9080
# Epoch 21/40 | Train Loss: 0.0417 | Val Loss: 0.0514 | Val RMSE: 0.9072
# Epoch 22/40 | Train Loss: 0.0411 | Val Loss: 0.0515 | Val RMSE: 0.9074
# Epoch 23/40 | Train Loss: 0.0402 | Val Loss: 0.0515 | Val RMSE: 0.9078
# Epoch 24/40 | Train Loss: 0.0395 | Val Loss: 0.0515 | Val RMSE: 0.9081
# Epoch 25/40 | Train Loss: 0.0382 | Val Loss: 0.0515 | Val RMSE: 0.9078
# Epoch 26/40 | Train Loss: 0.0378 | Val Loss: 0.0515 | Val RMSE: 0.9077
# Epoch 27/40 | Train Loss: 0.0373 | Val Loss: 0.0514 | Val RMSE: 0.9072
# Epoch 28/40 | Train Loss: 0.0369 | Val Loss: 0.0514 | Val RMSE: 0.9071
# Epoch 29/40 | Train Loss: 0.0365 | Val Loss: 0.0515 | Val RMSE: 0.9075
# Epoch 30/40 | Train Loss: 0.0361 | Val Loss: 0.0515 | Val RMSE: 0.9075
# Epoch 31/40 | Train Loss: 0.0354 | Val Loss: 0.0515 | Val RMSE: 0.9075
# Epoch 32/40 | Train Loss: 0.0353 | Val Loss: 0.0514 | Val RMSE: 0.9072
# Epoch 33/40 | Train Loss: 0.0351 | Val Loss: 0.0515 | Val RMSE: 0.9077
# Epoch 34/40 | Train Loss: 0.0347 | Val Loss: 0.0515 | Val RMSE: 0.9079
# Epoch 35/40 | Train Loss: 0.0346 | Val Loss: 0.0515 | Val RMSE: 0.9079
# Epoch 36/40 | Train Loss: 0.0345 | Val Loss: 0.0515 | Val RMSE: 0.9079
# Epoch 37/40 | Train Loss: 0.0343 | Val Loss: 0.0515 | Val RMSE: 0.9079
# Epoch 38/40 | Train Loss: 0.0342 | Val Loss: 0.0515 | Val RMSE: 0.9079
# Epoch 39/40 | Train Loss: 0.0342 | Val Loss: 0.0515 | Val RMSE: 0.9080
# Epoch 40/40 | Train Loss: 0.0342 | Val Loss: 0.0515 | Val RMSE: 0.9080
# Best Val RMSE: 0.9071
# Test RMSE: 0.9022

# %%
lightgcnpp_config = {
    'epochs': 12,
    'batch_size': 1024,
    'learning_rate': 0.001,
    'weight_decay': 1e-6,

    'embedding_dim': 48,
    'n_layers': 3,

    'device': device,
    'train_df': data_bundle[0]
}
trained_models['lightgcnpp'] = pipeline('lightgcnpp', lightgcnpp_config, data_bundle)
# Out:
# Training Model: best_lightgcnpp
# Epoch 1/12 | Train Loss: 0.0731 | Val Loss: 0.0654 | Val RMSE: 1.0226
# Epoch 2/12 | Train Loss: 0.0637 | Val Loss: 0.0615 | Val RMSE: 0.9921
# Epoch 3/12 | Train Loss: 0.0588 | Val Loss: 0.0585 | Val RMSE: 0.9673
# Epoch 4/12 | Train Loss: 0.0546 | Val Loss: 0.0562 | Val RMSE: 0.9481
# Epoch 5/12 | Train Loss: 0.0506 | Val Loss: 0.0548 | Val RMSE: 0.9362
# Epoch 6/12 | Train Loss: 0.0472 | Val Loss: 0.0539 | Val RMSE: 0.9283
# Epoch 7/12 | Train Loss: 0.0442 | Val Loss: 0.0532 | Val RMSE: 0.9225
# Epoch 8/12 | Train Loss: 0.0412 | Val Loss: 0.0528 | Val RMSE: 0.9195
# Epoch 9/12 | Train Loss: 0.0377 | Val Loss: 0.0530 | Val RMSE: 0.9205
# Epoch 10/12 | Train Loss: 0.0344 | Val Loss: 0.0532 | Val RMSE: 0.9229
# Epoch 11/12 | Train Loss: 0.0314 | Val Loss: 0.0536 | Val RMSE: 0.9264
# Epoch 12/12 | Train Loss: 0.0284 | Val Loss: 0.0541 | Val RMSE: 0.9301
# Best Val RMSE: 0.9195
# Test RMSE: 0.9218

# %%
simgcl_config = {
    'epochs': 10,
    'batch_size': 1024,
    'learning_rate': 0.002,
    'weight_decay': 1e-6,
    'embedding_dim': 64,
    'n_layers': 3,

    'eps': 0.1,
    'temperature': 0.2,
    'lambda_cl': 0.1,

    'device': device,
    'train_df': train_df
}
trained_models['simgcl'] = pipeline('simgcl', simgcl_config, data_bundle)
# Out:
# Training Model: best_simgcl
# Epoch 1/10 | Train Loss: 0.8007 | Val Loss: 0.0652 | Val RMSE: 1.0211
# Epoch 2/10 | Train Loss: 0.5778 | Val Loss: 0.0601 | Val RMSE: 0.9804
# Epoch 3/10 | Train Loss: 0.5597 | Val Loss: 0.0578 | Val RMSE: 0.9614
# Epoch 4/10 | Train Loss: 0.5512 | Val Loss: 0.0566 | Val RMSE: 0.9519
# Epoch 5/10 | Train Loss: 0.5454 | Val Loss: 0.0560 | Val RMSE: 0.9470
# Epoch 6/10 | Train Loss: 0.5415 | Val Loss: 0.0558 | Val RMSE: 0.9447
# Epoch 7/10 | Train Loss: 0.5386 | Val Loss: 0.0556 | Val RMSE: 0.9429
# Epoch 8/10 | Train Loss: 0.5366 | Val Loss: 0.0555 | Val RMSE: 0.9419
# Epoch 9/10 | Train Loss: 0.5346 | Val Loss: 0.0554 | Val RMSE: 0.9412
# Epoch 10/10 | Train Loss: 0.5337 | Val Loss: 0.0554 | Val RMSE: 0.9415
# Best Val RMSE: 0.9412
# Test RMSE: 0.9428

# %%
model_name = 'nmf'
# state = torch.load(f"best_{model_name}.pth", map_location="cpu")
# trained_models[model_name].load_state_dict(state)
trained_models[model_name].eval()
sample(
    model=trained_models[model_name],
    test_df=test_df,
    n_samples=7000,
    device=device
)
None
# Out:
#  userId  movieId  rating  predicted_rating  error  absolute_error
#     312      156     3.0              4.15   1.15            1.15
#     474       44     3.0              4.01   1.01            1.01
#     450      714     4.0              3.96  -0.04            0.04
#     345       14     4.0              4.20   0.20            0.20
#     655      315     4.0              3.28  -0.72            0.72
#     487      978     1.0              2.21   1.21            1.21
#     318      158     5.0              2.75  -2.25            2.25
#      60      665     4.0              3.45  -0.55            0.55
#     435       54     4.0              3.12  -0.88            0.88
#     864      710     2.0              4.00   2.00            2.00
#
# ----------------------------------------------------------------------------------------------------
# RMSE: 0.9169
# MAE: 0.7228

# %%
submission = generate_submission(
    movie_map=movie_map,
    user_map=user_map,
    train_df=train_df,
    model=trained_models[model_name],
    prompt_path=TEST_PATH,
    output_path=f"{model_name}.csv",
    device=device
)
# Out:
# Saved submission file to: nmf.csv
#    Id     Score
# 0   1  3.326147
# 1   2  2.766855
# 2   3  4.220539
# 3   4  4.108191
# 4   5  2.616639
